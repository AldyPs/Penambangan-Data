# %% [markdown]
# <a href="https://colab.research.google.com/github/AldyPs/Penambangan-Data/blob/master/Pertemuan1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
second_in_a_day = 20 * 60 * 60
second_in_a_day
# Out:
# 72000

# %%
second_in_a_week = 7 * second_in_a_day
second_in_a_week
# Out:
# 504000

# %%
import numpy as nmp
from matplotlib import pyplot as plt

ys = 200 + nmp.random.randn(100)
x = [x for x in range (len(ys))]

plt.plot(x,ys,'-')
plt.fill_between(x,ys, 195, where=(ys > 195), facecolor='g', alpha = 0.6)

plt.title("sample Visualization")
plt.show
# Out:
# <function matplotlib.pyplot.show>
